# %% [markdown]
# ---------
# # 2026
#
# # Limoges University
#
# ## CRYPTIS MASTER 2 - XLIM  - TP Exam
# ### Implementation and smart cards -- Side Channel Analysis
# -------
#
# Date: Wednesday 11th february 2026
#
# DURATION : 3H
# ----
#
# ----
# # SUBJECT
#
# ## Material for use for this exam
#
# The notebook ready to use (and to be used) is there: https://github.com/BeneoLix/Cryptis_2025_26
#
# * filename = 2026_02_11_TP_SCA_EXAMEN_TODO_English
#
# --> SO THIS FILE !
#
# And the traces are there: https://github.com/BeneoLix/SideSCA-Traces-Public
#
# * file with traces for exam part 1: filename = exam_2026_traces_set1.ets
# * file with traces for exam part 2: filename = exam_2026_traces_set2.ets
# * file with traces for exam part 3: filename = exam_2026_traces_set3_byte_"+str(key_byte)+".ets" with key_byte in {0, .., 15} (so 16 ets files)
#
# ## EXAM RULES
# - You can use all the files and work done during the TP sessions: notebooks, slides
# - You can use your personal laptop if you want
# - You can use internet except communication tools with others and any Intelligence Artificial tool
# - IT IS FORBIDDEN to discuss with others and to exchange information between you on the solutions
#     - if you exchange notebooks or solutions or files between you and that I can observe that then you will have penalty on the final note.
#
#
# ### 0. Clone / Download files into your Jupyter Lab or Notebook environnement in order to execute / use it
# ... as we made during our TP sessions.
#
#
# ### 1. Part I: first traces set "exam_2026_traces_set1.ets"
# * Realign the whole set of traces. I will replay the notebook to check the realignment is correct, no need to store the aligned traces in a file.
#
# ### 2. Part II: second traces set "exam_2026_traces_set2.ets"
# * Perform Simple Power Analysis on one and/or several traces (SPA) to recognize the cryptographic algorithm in the traces
# * Process the traces if needed and recover the secret key
# * Check you have recovered the correct key
#
# ### 3. Part III: third traces set "exam_2026_traces_set3_byte_"+str(key_byte)+".ets" with key_byte in {0, .., 15} (so 16 ets files)
# * These are chosen messages side-channel traces from a HW AES-128. You have a bit more than half the rounds of the AES
# * Identify the rounds, show it with colors in a plot.
# * Perform the attack using the chosen messages and recover the key
# * Keep in mind this is hardware, and if we are using chosen message there is a reason as we discussed in a related TP.
# * Keep in mind that attacking such chosen message cannot be done using HammingWeight and then there are many attacks possible as many bit values.
# * Use result visualisation, majority vote of results to identify if possible the good results
# * a couple (plaintext, ciphertext) is given for the final key recovery check
# * Brute force might not be needed but can be used in case you have doubts on some key bytes recovered
#
# ### The three parts can be done in the order you want.
#
# ### A DETAILED ANALYSIS AND EXPLANATIONS on what you do ARE EXPECTED and a CONCLUSION for each part.
#
# ## YOUR NOTEBOOK IS THE FILE TO PROVIDE TO ME AS EXAM COPY !!

# %% [markdown]
# ------
#
# ### Your work must be done in this notebook:
# - Use the cells in markdown mode to put your text and explanations
# - Use the cells in code mode to do your tests
# - Save the notebook with images
# - I will replay the notebook to verify when correcting
#
# ### Good luck !
# --------------------------
# --------------------------

# %% [markdown]
# -----------
# # * __NOM / NAME:__ PUT THERE
# # * __PRENOM / FIRSTNAME :__ PUT THERE
# --------

# %%
import ...

# %% [markdown]
# -------------
# ## Part I: traces alignment

# %%
ths = estraces.read_ths_from_ets_file("../SideSCA-Traces-Public/exam_2026_traces_set1.ets")
print(ths)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# -------------
# ## Part II: First key recovery

# %%
ths = estraces.read_ths_from_ets_file("../SideSCA-Traces-Public/exam_2026_traces_set2.ets")
print(ths)
# Out:
# Trace Header Set:
# Name.............: ETS Format THS
# Reader...........: ETS format reader of file ../SideSCA-Traces-Public/exam_2026_traces_set2.ets with 100 traces.
# ciphertext.......: uint8
# plaintext........: uint8

# %% [markdown]
# ## Conclusion

# %% [markdown]
# -------------
# ## Part III: Hardware AES

# %% [markdown]
# #### Given couple (plaintext, ciphertext)
#
#
# plaintext =  `0x00000000000000000000000000000000`
#
# ciphertext = `0x2e38d26c1714215d2a11d8dd9f46322f`

# %%
ths = estraces.read_ths_from_ets_file("../SideSCA-Traces-Public/exam_2026_traces_set3_byte_0.ets")
print(ths)
# Out:
# Trace Header Set:
# Name.............: ETS Format THS
# Reader...........: ETS format reader of file ../SideSCA-Traces-Public/exam_2026_traces_set3_byte_0.ets with 10000 traces.
# plaintext........: uint8

# %%
key_byte = 0

ths = estraces.read_ths_from_ets_file("../SideSCA-Traces-Public/exam_2026_traces_set3_byte_"+str(key_byte)+".ets")

.....

# %% [markdown]
# ## Conclusion
