# %% [markdown]
# ---------
# # 2026
#
# # Université de Limoges
#
# ## CRYPTIS MASTER 2 - XLIM  - Examen de TP
# ### Implementation et smart cards -- Side Channel Analysis
# -------
#
# Date: Mercredi 11 fevrier 2026
#
# DUREE : 3H
# ----
#
# ----
# # SUJET
#
# ## Materiel à utiliser pour l'examen
#
# Ce notebook est pret a être utilisé et doit être utilisé:  https://github.com/BeneoLix/Cryptis_2025_26
#
# * fichier = 2026_02_11_TP_SCA_EXAMEN_TODO_French
#
# --> donc ce notebook
#
# Les traces necessaires a l'examen sont ici: https://github.com/BeneoLix/SideSCA-Traces-Public
#
# * Fichier pour la partie 1 de l'examen : filename = exam_2026_traces_set1.ets
# * Fichier pour la partie 2 de l'examen : filename = exam_2026_traces_set2.ets
# * Fichier pour la partie 3 de l'examen : filename = exam_2026_traces_set3_byte_"+str(key_byte)+".ets" avec key_byte in {0, .., 15} (donc 16 fichier de traces dans ce cas)
#
# ## REGLES de l'examen
#
# - Vous avez le droit d'utiliser tout ce qui a été fait en TP : notebooks, le cours (slides).
# - Vous avez le droit d'utiliser votre ordinateur personnel.
# - Vous avez le droit d'utiliser internet : à l'exclusion de tout outil de communication avec autrui, et de tout outil d'intelligence artificielle.
# - Interdiction de communiquer et d'échanger entre vous.
#     - Si vous echangez des notebooks ou autres solutions par mail et que je detecte des choses similaires cela sera sanctionné / pénalisé pour les deux (ou plus) personnes.
#
# ### 0. Veuillez cloner ou télécharger ces fichiers et les mettre dans votre environnement Jupyter Lab (ou Jupyter notebook) pour les executer / utiliser
# ... de la même manière que ce que nous avons fait pendant les TPs.
#
#
# ### 1. Partie I: premier jeux de traces "exam_2026_traces_set1.ets"
# * Realignez toutes les traces de ce jeu de traces.
# Je rejouerai votre notebook pour vérifier les résultats. Pas besoin de stoquer les traces obtenue dans un fichier.
#
# ### 2. Partie II: second jeux de traces "exam_2026_traces_set2.ets"
# * faite une analyse simple (de type SPA) des traces afin de reconnaitre l'algorithme attaqué ...
# * Processez les traces si necessaire et retrouvez la clef en utilisant la CPA
# * Vérifiez que vous avez bien retrouvé la bonne clef
#
# ### 3. Part III: third traces set "exam_2026_traces_set3_byte_"+str(key_byte)+".ets" with key_byte in {0, .., 15} (so 16 ets files)
# * Vous avez des traces a messages choisis d'un AES Hardware AES-128. Vous avez un peu plus de la moitié de l'AES.
# * Identifiez les rondes, montrez les avec des couleurs / une legence dans un plot
# * Faites l'attaque en utilisant les messages choisis et retrouvez la clef
# * Gardez à l'esprit qu'il s'agit d'un AES Hardware, et que si l'on utilise des messages choisis il y a une raison comme discuté en TP.
# * Attaquer avec des messages choisis a peu de chances de reussir avec du HammingWeight et qu'il y a autant d'attaques que de bits choisis en monobit
# * Utilisez la visualisation des resultats, du vote majoritaires des attaques pour identifier si possible les bons guess d'octet(s)s de clef
# * un couple (plaintext, ciphertext) est donné pour la verification finale de key recovery
# * La force brute force n'est pas forcément nécéssaire mais peu servir en cas de doutes
#
# ### Les 3 parties peuvent etre faites dans l'ordre que vous voulez et sont independantes
#
# ### ### Des explications et des conclusions détaillées sont attendues.
#
# ## Vous devez me rendre le notebook comme copie.

# %% [markdown]
# ------
#
# ### Votre travail sera réalisé dans ce notebook:
# - Utilisez les cellules en mode markdown pour mettre votre texte, vos explications
# - Utiliser les cellules de code pour faire vos tests
# - Vous pouvez sauver le notebook avec les images
# - Je rejouerai le notebook de toue facon lors de la correction
#
# ### Bon examen de TP !
# --------------------------
# --------------------------

# %% [markdown]
# -----------
# # * __NOM / NAME:__ PUT THERE
# # * __PRENOM / FIRSTNAME :__ PUT THERE
# --------

# %%
import ...

# %% [markdown]
# -------------
# ## Part I: traces alignment

# %%
ths = estraces.read_ths_from_ets_file("../SideSCA-Traces-Public/exam_2026_traces_set1.ets")
print(ths)

# %% [markdown]
# ## Conclusion

# %% [markdown]
# -------------
# ## Part II: First key recovery

# %%
ths = estraces.read_ths_from_ets_file("../SideSCA-Traces-Public/exam_2026_traces_set2.ets")
print(ths)
# Out:
# Trace Header Set:
# Name.............: ETS Format THS
# Reader...........: ETS format reader of file ../SideSCA-Traces-Public/exam_2026_traces_set2.ets with 100 traces.
# ciphertext.......: uint8
# plaintext........: uint8

# %% [markdown]
# ## Conclusion

# %% [markdown]
# -------------
# ## Part III: Hardware AES

# %% [markdown]
# #### Given couple (plaintext, ciphertext)
#
#
# plaintext =  `0x00000000000000000000000000000000`
#
# ciphertext = `0x2e38d26c1714215d2a11d8dd9f46322f`

# %%
ths = estraces.read_ths_from_ets_file("../SideSCA-Traces-Public/exam_2026_traces_set3_byte_0.ets")
print(ths)
# Out:
# Trace Header Set:
# Name.............: ETS Format THS
# Reader...........: ETS format reader of file ../SideSCA-Traces-Public/exam_2026_traces_set3_byte_0.ets with 10000 traces.
# plaintext........: uint8

# %%
key_byte = 0

ths = estraces.read_ths_from_ets_file("../SideSCA-Traces-Public/exam_2026_traces_set3_byte_"+str(key_byte)+".ets")

.....

# %% [markdown]
# ## Conclusion
